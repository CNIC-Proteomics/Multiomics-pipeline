# %%
#
# Import libraries
#

import os
import pandas as pd
from dotmap import DotMap
import requests
import json
import numpy as np
from tqdm import tqdm
import time

# %%
modes = ['cp', 'cn', 'hp']
f2i_path = r"S:\U_Proteomica\UNIDAD\software\MacrosRafa\data\Metabolomics\PESA_Integromics\Data\Metabolomics\PESA_V2\OriginalFiles\RBR_f2i.xlsx"
f2i = DotMap({
    'cp': pd.read_excel(f2i_path, sheet_name='C18P').set_index('fid'),
    'cn': pd.read_excel(f2i_path, sheet_name='C18N').set_index('fid'),
    'hp': pd.read_excel(f2i_path, sheet_name='HILP').set_index('fid'),
})

# %%
#
# Obtain feature data for each CMM table and run TurboPutative
#

xm = pd.read_csv(
    r"S:\U_Proteomica\UNIDAD\software\MacrosRafa\data\Metabolomics\PESA_Integromics\Data\Metabolomics\PESA_V2\WorkingFiles\Xm_norm.tsv", 
    sep='\t', index_col=0)

# %%
#
# Adducts
#

posAdd = ["M+H", "M+2H", "M+Na", "M+K", "M+H-H2O", "M+H+HCOONa"]
negAdd = ["M-H", "M-2H", "M+Cl", "M-H-H20", "M-H+HCOONa", "M+Na-2H", "M+HCOOH-H"]

# %% [markdown]
# C18P

# %%
mz = f2i.cp.loc[
    np.isin(f2i.cp.index, xm.columns),
    'Apex m/z'
].tolist()

n=5
mz = [mz[i:i+n] for i in range(0, len(mz), n)]

# %%
cmm = DotMap()

uri = "http://ceumass.eps.uspceu.es/mediator/api/v3/batch"

# C18P
res_all = []

for mzi in tqdm(mz):
    res = requests.post(
        uri, headers={'Content-Type': 'application/json; charset=utf-8'}, 
        json={
        "metabolites_type": "all-except-peptides",
        "databases": ["all-except-mine"],
        "masses_mode": "mz",
        "ion_mode": "positive",
        "adducts": posAdd,
        "tolerance": 10.0,
        "tolerance_mode": "ppm",
        "masses": mzi
        }
    )
    res_all.extend(res.json()['results'])
    time.sleep(2)

cmm.cp = pd.DataFrame(res_all)
# Out:
# 100%|██████████| 83/83 [03:09<00:00,  2.28s/it]

# %% [markdown]
# C18N

# %%
mz = f2i.cn.loc[
    np.isin(f2i.cn.index, xm.columns),
    'Apex m/z'
].tolist()

n=5
mz = [mz[i:i+n] for i in range(0, len(mz), n)]

# %%
# C18N
res_all = []

for mzi in tqdm(mz):
    res = requests.post(
        uri, headers={'Content-Type': 'application/json; charset=utf-8'}, 
        json={
        "metabolites_type": "all-except-peptides",
        "databases": ["all-except-mine"],
        "masses_mode": "mz",
        "ion_mode": "negative",
        "adducts": ['all'],
        "tolerance": 10.0,
        "tolerance_mode": "ppm",
        "masses": mzi
        }
    )
    res_all.extend(res.json()['results'])
    time.sleep(2)

cmm.cn = pd.DataFrame(res_all)
# Out:
#   0%|          | 0/78 [00:00<?, ?it/s]
# 100%|██████████| 78/78 [03:33<00:00,  2.74s/it]

# %% [markdown]
# HILP

# %%
mz = f2i.hp.loc[
    np.isin(f2i.hp.index, xm.columns),
    'Apex m/z'
].tolist()

n=2
mz = [mz[i:i+n] for i in range(0, len(mz), n)]

# %%
# HILP
res_all = []

for mzi in tqdm(mz):
    res = requests.post(
        uri, headers={'Content-Type': 'application/json; charset=utf-8'}, 
        json={
        "metabolites_type": "all-except-peptides",
        "databases": ["all-except-mine"],
        "masses_mode": "mz",
        "ion_mode": "positive",
        "adducts": posAdd,
        "tolerance": 5.0,
        "tolerance_mode": "ppm",
        "masses": mzi
        }
    )
    res_all.extend(res.json()['results'])
    time.sleep(2)

cmm.hp = pd.DataFrame(res_all)
# Out:
#  29%|██▉       | 74/253 [09:48<23:43,  7.95s/it]
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# c:\Users\rbarreror\AppData\Local\Programs\Python\Python310\lib\site-packages\requests\models.py in json(self, **kwargs)
#     909         try:
# --> 910             return complexjson.loads(self.text, **kwargs)
#     911         except JSONDecodeError as e:
#
# c:\Users\rbarreror\AppData\Local\Programs\Python\Python310\lib\site-packages\simplejson\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, use_decimal, **kw)
#     524             and not use_decimal and not kw):
# --> 525         return _default_decoder.decode(s)
#     526     if cls is None:
#
# c:\Users\rbarreror\AppData\Local\Programs\Python\Python310\lib\site-packages\simplejson\decoder.py in decode(self, s, _w, _PY3)
#     369             s = str(s, self.encoding)
# --> 370         obj, end = self.raw_decode(s)
#     371         end = _w(s, end).end()
#
# c:\Users\rbarreror\AppData\Local\Programs\Python\Python310\lib\site-packages\simplejson\decoder.py in raw_decode(self, s, idx, _w, _PY3)
#     399                 idx += 3
# --> 400         return self.scan_once(s, idx=_w(s, idx).end())
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_31420\3729969294.py in <cell line: 4>()
#      16         }
#      17     )
# ---> 18     res_all.extend(res.json()['results'])
#      19     time.sleep(2)
#      20
#
# c:\Users\rbarreror\AppData\Local\Programs\Python\Python310\lib\site-packages\requests\models.py in json(self, **kwargs)
#     915                 raise RequestsJSONDecodeError(e.message)
#     916             else:
# --> 917                 raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#     918
#     919     @property
#
# JSONDecodeError: [Errno Expecting value] <!DOCTYPE HTML PUBLIC "-//IETF//DTD HTML 2.0//EN">
# <html><head>
# <title>502 Proxy Error</title>
# </head><body>
# <h1>Proxy Error</h1>
# <p>The proxy server received an invalid
# response from an upstream server.<br />
# The proxy server could not handle the request<p>Reason: <strong>Error reading from remote server</strong></p></p>
# <hr>
# <address>Apache/2.4.10 (Debian) Server at ceumass.eps.uspceu.es Port 80</address>
# </body></html>
# : 0

# %%
cmmF = DotMap()
cmmF.cp = cmm.cp[np.isin(cmm.cp.adduct, posAdd)]
cmmF.cn = cmm.cn[np.isin(cmm.cn.adduct, negAdd)]
# cmmF.hp = cmm.hp[np.isin(cmm.hp.adduct, posAdd)]

# %%
for i in ['cp', 'cn']:#, 'hp']:
    print(i)
    print('Number of features: ' + str((~cmm[i].EM.duplicated()).sum()))
    print('Number of annotations: ' + str(cmm[i].shape[0]))
    print('Number of filtered annotations: ' + str(cmmF[i].shape[0]))
# Out:
# cp
# Number of features: 357
# Number of annotations: 11961
# Number of filtered annotations: 11961
# cn
# Number of features: 387
# Number of annotations: 41776
# Number of filtered annotations: 19666

# %%
# Adapt columns to TP

for i in ['cp', 'cn']:#, 'hp']:
    cmmF[i] = cmmF[i].rename(columns={
        'identifier': 'Identifier',
        'EM': 'Experimental mass',
        'adduct': 'Adduct',
        'error_ppm': 'mz Error (ppm)',
        'molecular_weight': 'Molecular Weight',
        'name': 'Name',
        'formula': 'Formula'
    })

# %%
# Identifiers to be removed
remid = [188282]

# %%
# Write MS_Table.tsv
for i in ['cp', 'cn']:#, 'hp']:
    cmmF[i][~np.isin(cmmF[i].Identifier, remid)].to_csv(f'CMM_{i}.tsv', sep='\t', index=False)

# %%
# Out:
# ['seqn_6',
#  'seqn_8',
#  'seqn_9',
#  'seqn_11',
#  'seqn_16',
#  'seqn_17',
#  'seqn_26',
#  'seqn_34',
#  'seqn_35',
#  'seqn_38',
#  'seqn_41',
#  'seqn_45',
#  'seqn_52',
#  'seqn_56',
#  'seqn_57',
#  'seqn_58',
#  'seqn_73',
#  'seqn_84',
#  'seqn_87',
#  'seqn_91',
#  'seqn_96',
#  'seqn_97',
#  'seqn_109',
#  'seqn_115',
#  'seqn_121',
#  'seqn_125',
#  'seqn_131',
#  'seqn_138',
#  'seqn_140',
#  'seqn_169',
#  'seqn_175',
#  'seqn_188',
#  'seqn_194',
#  'seqn_207',
#  'seqn_219',
#  'seqn_227',
#  'seqn_243',
#  'seqn_255',
#  'seqn_257',
#  'seqn_266',
#  'seqn_269',
#  'seqn_271',
#  'seqn_279',
#  'seqn_280',
#  'seqn_296',
#  'seqn_299',
#  'seqn_302',
#  'seqn_307',
#  'seqn_319',
#  'seqn_344',
#  'seqn_345',
#  'seqn_361',
#  'seqn_364',
#  'seqn_370',
#  'seqn_385',
#  'seqn_398',
#  'seqn_411',
#  'seqn_439',
#  'seqn_442',
#  'seqn_443',
#  'seqn_444',
#  'seqn_449',
#  'seqn_456',
#  'seqn_461',
#  'seqn_466',
#  'seqn_496',
#  'seqn_508',
#  'seqn_520',
#  'seqn_522',
#  'seqn_525',
#  'seqn_546',
#  'seqn_551',
#  'seqn_559',
#  'seqn_575',
#  'seqn_592',
#  'seqn_600',
#  'seqn_603',
#  'seqn_610',
#  'seqn_630',
#  'seqn_632',
#  'seqn_637',
#  'seqn_647',
#  'seqn_648',
#  'seqn_650',
#  'seqn_661',
#  'seqn_675',
#  'seqn_679',
#  'seqn_710',
#  'seqn_716',
#  'seqn_718',
#  'seqn_721',
#  'seqn_729',
#  'seqn_751',
#  'seqn_755',
#  'seqn_758',
#  'seqn_759',
#  'seqn_763',
#  'seqn_811',
#  'seqn_840',
#  'seqn_842',
#  'seqn_849',
#  'seqn_864',
#  'seqn_865',
#  'seqn_872',
#  'seqn_886',
#  'seqn_898',
#  'seqn_906',
#  'seqn_918',
#  'seqn_937',
#  'seqn_939',
#  'seqn_958',
#  'seqn_962',
#  'seqn_968',
#  'seqn_979',
#  'seqn_995',
#  'seqn_1003',
#  'seqn_1019',
#  'seqn_1024',
#  'seqn_1027',
#  'seqn_1033',
#  'seqn_1037',
#  'seqn_1046',
#  'seqn_1050',
#  'seqn_1053',
#  'seqn_1056',
#  'seqn_1060',
#  'seqn_1073',
#  'seqn_1079',
#  'seqn_1093',
#  'seqn_1097',
#  'seqn_1099',
#  'seqn_1108',
#  'seqn_1116',
#  'seqn_1122',
#  'seqn_1134',
#  'seqn_1142',
#  'seqn_1144',
#  'seqn_1163',
#  'seqn_1167',
#  'seqn_1169',
#  'seqn_1174',
#  'seqn_1187',
#  'seqn_1188',
#  'seqn_1192',
#  'seqn_1194',
#  'seqn_1195',
#  'seqn_1202',
#  'seqn_1208',
#  'seqn_1217',
#  'seqn_1223',
#  'seqn_1224',
#  'seqn_1228',
#  'seqn_1232',
#  'seqn_1239',
#  'seqn_1253',
#  'seqn_1257',
#  'seqn_1259',
#  'seqn_1260',
#  'seqn_1264',
#  'seqn_1265',
#  'seqn_1270',
#  'seqn_1297',
#  'seqn_1316',
#  'seqn_1319',
#  'seqn_1339',
#  'seqn_1341',
#  'seqn_1364',
#  'seqn_1370',
#  'seqn_1385',
#  'seqn_1394',
#  'seqn_1395',
#  'seqn_1398',
#  'seqn_1401',
#  'seqn_1405',
#  'seqn_1409',
#  'seqn_1411',
#  'seqn_1413',
#  'seqn_1418',
#  'seqn_1425',
#  'seqn_1430',
#  'seqn_1435',
#  'seqn_1436',
#  'seqn_1438',
#  'seqn_1443',
#  'seqn_1446',
#  'seqn_1447',
#  'seqn_1450',
#  'seqn_1458',
#  'seqn_1473',
#  'seqn_1477',
#  'seqn_1505',
#  'seqn_1513',
#  'seqn_1521',
#  'seqn_1532',
#  'seqn_1539',
#  'seqn_1544',
#  'seqn_1563',
#  'seqn_1570',
#  'seqn_1583',
#  'seqn_1611',
#  'seqn_1624',
#  'seqn_1625',
#  'seqn_1630',
#  'seqn_1633',
#  'seqn_1645',
#  'seqn_1666',
#  'seqn_1674',
#  'seqn_1681',
#  'seqn_1683',
#  'seqn_1684',
#  'seqn_1693',
#  'seqn_1699',
#  'seqn_1700',
#  'seqn_1721',
#  'seqn_1723',
#  'seqn_1729',
#  'seqn_1736',
#  'seqn_1758',
#  'seqn_1759',
#  'seqn_1772',
#  'seqn_1784',
#  'seqn_1789',
#  'seqn_1791',
#  'seqn_1801',
#  'seqn_1803',
#  'seqn_1810',
#  'seqn_1821',
#  'seqn_1824',
#  'seqn_1830',
#  'seqn_1831',
#  'seqn_1840',
#  'seqn_1850',
#  'seqn_1852',
#  'seqn_1860',
#  'seqn_1863',
#  'seqn_1873',
#  'seqn_1879',
#  'seqn_1889',
#  'seqn_1891',
#  'seqn_1898',
#  'seqn_1928',
#  'seqn_1930',
#  'seqn_1938',
#  'seqn_1943',
#  'seqn_1952',
#  'seqn_1955',
#  'seqn_1956',
#  'seqn_1957',
#  'seqn_1966',
#  'seqn_1969',
#  'seqn_1981',
#  'seqn_1990',
#  'seqn_1992',
#  'seqn_1996',
#  'seqn_1998',
#  'seqn_2002',
#  'seqn_2015',
#  'seqn_2017',
#  'seqn_2018',
#  'seqn_2028',
#  'seqn_2041',
#  'seqn_2045',
#  'seqn_2049',
#  'seqn_2054',
#  'seqn_2056',
#  'seqn_2057',
#  'seqn_2062',
#  'seqn_2066',
#  'seqn_2073',
#  'seqn_2076',
#  'seqn_2079',
#  'seqn_2081',
#  'seqn_2089',
#  'seqn_2092',
#  'seqn_2097',
#  'seqn_2098',
#  'seqn_2104',
#  'seqn_2105',
#  'seqn_2106',
#  'seqn_2110',
#  'seqn_2113',
#  'seqn_2119',
#  'seqn_2129',
#  'seqn_2142',
#  'seqn_2144',
#  'seqn_2149',
#  'seqn_2157',
#  'seqn_2159',
#  'seqn_2166',
#  'seqn_2173',
#  'seqn_2180',
#  'seqn_2189',
#  'seqn_2193',
#  'seqn_2202',
#  'seqn_2220',
#  'seqn_2226',
#  'seqn_2259',
#  'seqn_2263',
#  'seqn_2271',
#  'seqn_2285',
#  'seqn_2292',
#  'seqn_2299',
#  'seqn_2300',
#  'seqn_2310',
#  'seqn_2315',
#  'seqn_2322',
#  'seqn_2359',
#  'seqn_2364',
#  'seqn_2385',
#  'seqn_2392',
#  'seqn_2404',
#  'seqn_2406',
#  'seqn_2415',
#  'seqn_2420',
#  'seqn_2439',
#  'seqn_2457',
#  'seqn_2458',
#  'seqn_2461',
#  'seqn_2465',
#  'seqn_2479',
#  'seqn_2482',
#  'seqn_2501',
#  'seqn_2507',
#  'seqn_2508',
#  'seqn_2557',
#  'seqn_2573',
#  'seqn_2575',
#  'seqn_2582',
#  'seqn_2587',
#  'seqn_2606',
#  'seqn_2627',
#  'seqn_2638',
#  'seqn_2650',
#  'seqn_2661',
#  'seqn_2671',
#  'seqn_2673',
#  'seqn_2681',
#  'seqn_2682',
#  'seqn_2683',
#  'seqn_2691',
#  'seqn_2692',
#  'seqn_2709',
#  'seqn_2716',
#  'seqn_2730',
#  'seqn_2750',
#  'seqn_2752',
#  'seqn_2753',
#  'seqn_2782',
#  'seqn_2783',
#  'seqn_2784',
#  'seqn_2798',
#  'seqn_2811',
#  'seqn_2827',
#  'seqn_2828',
#  'seqn_2838',
#  'seqn_2845',
#  'seqn_2859',
#  'seqn_2860',
#  'seqn_2880',
#  'seqn_2892',
#  'seqn_2915',
#  'seqn_2917',
#  'seqn_2921',
#  'seqn_2922',
#  'seqn_2924',
#  'seqn_2941',
#  'seqn_2948',
#  'seqn_2950',
#  'seqn_2952',
#  'seqn_2961',
#  'seqn_2964',
#  'seqn_2975',
#  'seqn_2976',
#  'seqn_2983',
#  'seqn_2990',
#  'seqn_2991',
#  'seqn_2996',
#  'seqn_2998',
#  'seqn_2999',
#  'seqn_3004',
#  'seqn_3025',
#  'seqn_3037',
#  'seqn_3040',
#  'seqn_3046',
#  'seqn_3057',
#  'seqn_3074',
#  'seqn_3082',
#  'seqn_3088',
#  'seqn_3090',
#  'seqn_3096',
#  'seqn_3146',
#  'seqn_3169',
#  'seqn_3170',
#  'seqn_3178',
#  'seqn_3185',
#  'seqn_3205',
#  'seqn_3243',
#  'seqn_3263',
#  'seqn_3280',
#  'seqn_3288',
#  'seqn_3295',
#  'seqn_3298',
#  'seqn_3301',
#  'seqn_3319',
#  'seqn_3332',
#  'seqn_3335',
#  'seqn_3339',
#  'seqn_3346',
#  'seqn_3355',
#  'seqn_3358',
#  'seqn_3363',
#  'seqn_3375',
#  'seqn_3408',
#  'seqn_3422',
#  'seqn_3427',
#  'seqn_3428',
#  'seqn_3448',
#  'seqn_3463',
#  'seqn_3472',
#  'seqn_3479',
#  'seqn_3499',
#  'seqn_3512',
#  'seqn_3513',
#  'seqn_3521',
#  'seqn_3531',
#  'seqn_3597',
#  'seqn_3615',
#  'seqn_3619',
#  'seqn_3665',
#  'seqn_3677',
#  'seqn_3698',
#  'seqn_3722',
#  'seqn_3723',
#  'seqn_3725',
#  'seqn_3765',
#  'seqn_3804',
#  'seqn_3844',
#  'seqn_3860',
#  'seqn_3861',
#  'seqn_3867']

# %%
# Write Feature_Info.tsv
xm_tp = xm.copy()
xm_tp.index = [f'seqn_{i}' for i in xm_tp.index]
for i in ['cp', 'cn']:#, 'hp']:
    f2i[i].loc[
        np.isin(f2i[i].index, xm.columns),
        ['Apex m/z', 'RT [min]']
    ].join(xm_tp.T, how='inner')\
            .reset_index(names='FeatureInfo_Name')\
                .to_csv(f'FInfo_{i}.tsv', sep='\t', index=False)
