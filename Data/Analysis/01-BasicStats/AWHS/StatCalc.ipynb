# %%
#
# Import Libraries
#

import os
import sys
import pandas as pd
import numpy as np

utilsPath = r'S:\U_Proteomica\UNIDAD\software\MacrosRafa\data\Metabolomics\PESA_Integromics\Data\utils'
if utilsPath not in sys.path:
    sys.path.append(utilsPath)

from BasicStats import Xstats

# %%
#
# Set constants
#

Qworking_path = r"S:\U_Proteomica\UNIDAD\software\MacrosRafa\data\Metabolomics\PESA_Integromics\Data\Proteomics\AWHS"
Mworking_path = r"S:\U_Proteomica\UNIDAD\software\MacrosRafa\data\Metabolomics\PESA_Integromics\Data\Metabolomics\AWHS"

# X
xq_path = os.path.join(Qworking_path, "WorkingFiles", "Xq_minus_X_norm.tsv")
mq_path = os.path.join(Mworking_path, "WorkingFiles", "Xm_norm_MS2.tsv")

# Feature info
q2i_path = os.path.join(Qworking_path, "WorkingFiles", "q2info.tsv")
m2i_path = os.path.join(Mworking_path, "WorkingFiles", "m2info.tsv")

# metadata
mdata_path = os.path.join(r"S:\U_Proteomica\UNIDAD\software\MacrosRafa\data\Metabolomics\PESA_Integromics\Data\Metadata\AWHS\WorkingFiles\main_metadata.tsv")

# %%
#
# Read data
#

xq = pd.read_csv(xq_path, sep='\t', index_col=0)
xm = pd.read_csv(mq_path, sep='\t', index_col=0)

q2i = pd.read_csv(q2i_path, sep='\t')
m2i = pd.read_csv(m2i_path, sep='\t')

mdata = pd.read_csv(mdata_path, sep='\t', index_col=0)

# %%
#
# Parameters
#

qualCols = ['Caso/control', 'diabetes', 'smoker', 'HIPERTENSION_RF', 'DISLIPEMIA_RF']
quanCols = ['Plaque thickness', 'Glucosa', 'Calcio Score', 'age', 'coltot', 'hdl', 'presis', 'presdi']

# %%
# Create Xstats object

xqs = Xstats(mdata, xq, qualCols, quanCols)
xms = Xstats(mdata, xm, qualCols, quanCols)

# %%
# Simple Logistic Regression

xqs.LogR()
xms.LogR()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.641101
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.666954
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.692959
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.692184
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.687290
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.692761
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.681241
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.684184
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.686394
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.691346
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.683030
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.692089
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.689542
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.692813
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.691889
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.693128
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.667793
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.683293
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.691891
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.657443
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.670573
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.688734
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.685518
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.685318
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.692308
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.659799
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.665881
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.679499
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.680896
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.691549
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.693130
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.693069
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.688756
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.685360
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.682946
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.680553
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.691029
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.684101
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.692182
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.691975
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.692731
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.648950
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.693075
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.683145
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.677275
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.679065
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.689691
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.692898
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.680690
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.653983
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.691268
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.687176
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.690527
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.687623
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.675725
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.692425
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.684565
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.693134
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.675529
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.691461
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.669424
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.679071
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.692866
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.674949
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.691496
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.692379
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.692814
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.690925
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.672099
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.691988
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.691765
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.687069
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.689949
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.693115
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.693142
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.692873
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.681064
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.680727
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.679978
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.689711
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.691793
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.676300
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.677295
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.693006
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.685363
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.687571
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.693092
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.676059
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.693087
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.693023
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.690001
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.685957
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.692960
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.677349
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.689483
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.690817
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.679539
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.692419
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.692226
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.693067
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.693140
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.692546
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.673827
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.693142
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.690568
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.674584
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.690164
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.692526
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.684630
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.681012
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.687532
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.682131
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.692530
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.691288
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.685594
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.692257
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.692434
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.690051
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.692715
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.693077
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.671816
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.692652
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.682637
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.691665
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.692434
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.680370
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.692388
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.692018
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.671448
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.692799
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.686922
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.692895
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.685431
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.662034
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.690309
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.692022
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.681345
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.664822
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.657230
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.673909
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.675699
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.671128
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.650068
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.671802
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.675126
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.659495
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.648527
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.658300
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.659481
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.669650
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.669222
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.649258
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.648097
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.654459
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.639309
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.666170
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.665511
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.673526
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.674030
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.649819
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.671762
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.635762
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.663660
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.650768
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.675313
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.675672
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.675659
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.675667
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.671865
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.641638
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.675370
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.675091
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.675288
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.667022
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.670339
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.674545
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.675499
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.673940
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.664855
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.671266
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.670769
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.671734
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.650894
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.659450
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.670163
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.675564
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.673034
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.675322
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.670962
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.670820
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.669917
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.670299
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.675636
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.675693
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.655718
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.670836
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.675696
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.649971
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.675367
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.667057
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.675703
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.673967
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.675609
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.674373
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.656792
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.674485
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.654152
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.670760
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.654945
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.668350
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.675703
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.675673
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.647508
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.637953
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.675376
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.662928
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.675325
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.673701
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.660559
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.670701
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.670465
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.674290
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.654132
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.666485
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.670223
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.660361
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.654977
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.666982
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.674343
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.666056
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.665629
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.674898
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.674798
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.668013
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.661327
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.652733
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.658424
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.669598
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.667111
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.660739
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.669946
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.669235
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.675707
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.659791
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.663399
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.658636
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.666607
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.660827
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.641734
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.674809
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.670016
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.672921
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.674770
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.647032
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.664080
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.666025
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.674550
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.675606
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.673625
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.664376
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.675193
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.652721
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.674597
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.655588
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.674287
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.675120
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.647852
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.662967
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.675708
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.638667
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.672270
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.674944
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.674896
#          Iterations 4

# %%
# Multiple Logistic Regression

xqs.MLogR(topN=20)
xms.MLogR(topN=20)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.451976
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.044172
#          Iterations 14
# Optimization terminated successfully.
#          Current function value: 0.531126
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.483344
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.504790
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.615805
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.080102
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.562736
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.547340
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.579842
#          Iterations 6

# %%
# Regularised Multiple Logistic Regression

xqs.RMLogR(topN=100)
xms.RMLogR(topN=100)
# Out:
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.3317921978331709
#             Iterations: 145
#             Function evaluations: 145
#             Gradient evaluations: 145
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.07795773793354432
#             Iterations: 158
#             Function evaluations: 158
#             Gradient evaluations: 158
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.43817906637613824
#             Iterations: 134
#             Function evaluations: 134
#             Gradient evaluations: 134
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.41005290577374287
#             Iterations: 111
#             Function evaluations: 112
#             Gradient evaluations: 111
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.3968498872936556
#             Iterations: 124
#             Function evaluations: 124
#             Gradient evaluations: 124
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.5646754400285953
#             Iterations: 291
#             Function evaluations: 292
#             Gradient evaluations: 291
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.11800181501263862
#             Iterations: 204
#             Function evaluations: 205
#             Gradient evaluations: 204
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.46081697962100776
#             Iterations: 277
#             Function evaluations: 278
#             Gradient evaluations: 277
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.5548286621497748
#             Iterations: 189
#             Function evaluations: 190
#             Gradient evaluations: 189
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.5592352433508003
#             Iterations: 163
#             Function evaluations: 165
#             Gradient evaluations: 163

# %%
# Linear Regression

xqs.LinR()
xms.LinR()

# %%
# Multiple Linear Regression

xqs.MLinR(topN=100)
xms.MLinR(topN=100)

# %%
# Correlations (Pearson, Spearman, Kendall)

xqs.correlations()
xms.correlations()

# %%
# T-test & U-test (Mann-Whitney)

xqs.TUtest()
xms.TUtest()

# %%
# FDR using BH

xqs.FDR()
xms.FDR()

# %%
# Write df

xqs.export().to_csv('Xq_stats.tsv', sep='\t')
xms.export().to_csv('Xm_stats.tsv', sep='\t')
